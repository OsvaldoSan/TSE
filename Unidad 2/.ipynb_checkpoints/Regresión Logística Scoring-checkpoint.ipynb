# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,roc_auc_score

import os
from functools import reduce

from scipy.stats import ks_2samp
from scikitplot.metrics import plot_ks_statistic,plot_roc_curve

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',500)
pd.set_option('display.float_format',lambda x:'%.4f'%x)

# %% [markdown]
# ## Cargar datos y categorizar variables

# %%
ruta='/home/oszwaldo/Documentos/Projects/Selectos/Unidad 2/Hojas de cálculo'
r=os.listdir('/home/oszwaldo/Documentos/Projects/Selectos/Unidad 2/Hojas de cálculo')[2]
arch= os.path.join(ruta,r)
arch
# Out:
# '/home/oszwaldo/Documentos/Projects/Selectos/Unidad 2/Hojas de cálculo/Cuestionario Diagnóstico 2019 - 1 (Respuestas).xlsx'

# %%
df = pd.read_excel(arch)
print(df.shape)
df = df.loc[df['Edad 🎂']<=40].reset_index(drop=True)
df = df.loc[df['¿Cuántos cuartos para dormir tiene tu vivienda?']>0].reset_index(drop=True)
df = df.loc[df['¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?']<=100000].reset_index(drop=True)
df = df.loc[df['¿En cuántos años lo terminaste?']<=5].reset_index(drop=True)
print(df.shape)
# Out:
# (228, 81)
# (222, 81)

# %%
varc = ['Edad 🎂',
        '¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱',
        '¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti',
        '¿Cuántos son hombres?',
        '¿Cuántas son mujeres?',
        '¿Cuánto tiempo llevas viviendo ahí? (años)',
        '¿Cuántos cuartos para dormir tiene tu vivienda?',
        '¿Cuántos automóviles en total tienen las personas que conforman tu hogar?',
        '¿Cuántas horas trabajas a la semana?',
        '¿Qué promedio obtuviste en el bachillerato?',
        '¿En cuántos años lo terminaste?',
        '¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?',
        '¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]',
        '¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]',
        '¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]',
        '¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]'
       ]

vard = ['Estado civil','¿Tienes hijos?',
        '¿Tienes alguna dificultad para? [👓 Ver]',
        '¿Tienes alguna dificultad para? [👂 Escuchar]',
        '¿Tienes alguna dificultad para? [💪 Realizar alguna actividad física]',
        '¿Dónde vives actualmente?',
        '¿En qué delegación o municipio?',
        '¿Qué medio de transporte utilizas para llegar a la facultad?',
        '¿Cuál de las siguientes opciones describe tu tipo de vivienda?',
        '¿Con quién vives? (Puedes seleccionar más de una)',
        '¿Cuál es el máximo nivel de estudios de tu papá?',
        '¿Cuál es el máximo nivel de estudios de tu mamá?',
        'En caso de que tengas smartphone ¿Qué sistema operativo tiene?',
        '¿Dónde vivirás mientras cursas tus estudios universitarios?',
        '¿De qué forma financiarás tus estudios universitarios?',
        '¿En dónde cursaste el bachillerato?','¿Cómo se llama la institución donde cursaste el bachillerato?',
        '¿Recibiste alguna beca?','¿Cuál fue el proceso de admisión por el que entraste a esta carrera?',
        'Escoger ésta carrera fue...','Al escoger la FES Acatlán ésta fue:',
        '¿Cuándo tomaste la decisión de lo que querías estudiar?'   
       ]
tgt = 'Carrera'

# %% [markdown]
# ## Normalizar variables discretas

# %%
for v in vard:
    df[v].fillna('MISSING',inplace=True)

# %%
def normalizar(df,v,umbral=0.05):
    aux = df[v].value_counts(True).to_frame()
    aux['norm'] = np.where(aux[v]<umbral,'Otros',aux.index)
    grupo = aux.loc[aux['norm']=='Otros'][v].sum()
    if grupo<umbral:
        aux['norm'].replace({'Otros':aux.index[0]},inplace=True)
    aux.drop(v,axis=1,inplace=True)
    return v,aux.to_dict()['norm']

# %%
l_norm = list(map(lambda v:normalizar(df,v),vard)    )

# %%
normalizar(df,'Estado civil')
# Out:
# ('Estado civil',
#  {'👤 Soltero': '👤 Soltero',
#   '👥 En una relación': '👥 En una relación',
#   '💍 Casado': '👤 Soltero'})

# %%
f'n_{vard[0]}'
# Out:
# 'n_Estado civil'

# %%
for v,d in l_norm:
    df[f'n_{v}'] = df[v].replace(d)

# %%
varn = df.filter(like='n_').columns.tolist()

# %%
for v in varn:
    print(v,'\n')
    print(df[v].value_counts(True).sort_index())
    print('\n'*2)
# Out:
# n_Estado civil
#
# 👤 Soltero           0.7793
# 👥 En una relación   0.2207
# Name: n_Estado civil, dtype: float64
#
#
#
# n_¿Tienes hijos?
#
# No   1.0000
# Name: n_¿Tienes hijos?, dtype: float64
#
#
#
# n_¿Tienes alguna dificultad para? [👓 Ver]
#
# No   0.5135
# Si   0.4865
# Name: n_¿Tienes alguna dificultad para? [👓 Ver], dtype: float64
#
#
#
# n_¿Tienes alguna dificultad para? [👂 Escuchar]
#
# No   1.0000
# Name: n_¿Tienes alguna dificultad para? [👂 Escuchar], dtype: float64
#
#
#
# n_¿Tienes alguna dificultad para? [💪 Realizar alguna actividad física]
#
# No   1.0000
# Name: n_¿Tienes alguna dificultad para? [💪 Realizar alguna actividad física], dtype: float64
#
#
#
# n_¿Dónde vives actualmente?
#
# CDMX               0.3829
# Estado de México   0.6171
# Name: n_¿Dónde vives actualmente?, dtype: float64
#
#
#
# n_¿En qué delegación o municipio?
#
# Naucalpan   0.0856
# Otros       0.9144
# Name: n_¿En qué delegación o municipio?, dtype: float64
#
#
#
# n_¿Qué medio de transporte utilizas para llegar a la facultad?
#
# Transporte público (metro, metrobus, micro, combi, etc.)   0.8784
# Vehículo propio (Automóvil, motocicleta, motoneta)         0.1216
# Name: n_¿Qué medio de transporte utilizas para llegar a la facultad?, dtype: float64
#
#
#
# n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?
#
# Ocupada sin pagar renta (incluye casa de familiares)   0.1847
# Propia (se esta pagando)                               0.1892
# Propia (ya esta pagada)                                0.4865
# Rentada                                                0.1396
# Name: n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?, dtype: float64
#
#
#
# n_¿Con quién vives? (Puedes seleccionar más de una)
#
# Otros                               0.4009
# 👩🏽 Mamá, 👦🏽👧🏽 Hermano(s)            0.0946
# 👩🏽 Mamá, 👨🏽 Papá                    0.0631
# 👩🏽 Mamá, 👨🏽 Papá, 👦🏽👧🏽 Hermano(s)   0.4414
# Name: n_¿Con quién vives? (Puedes seleccionar más de una), dtype: float64
#
#
#
# n_¿Cuál es el máximo nivel de estudios de tu papá?
#
# Bachillerato   0.3198
# Licenciatura   0.2793
# Otros          0.0766
# Primaria       0.0721
# Secundaria     0.2523
# Name: n_¿Cuál es el máximo nivel de estudios de tu papá?, dtype: float64
#
#
#
# n_¿Cuál es el máximo nivel de estudios de tu mamá?
#
# Bachillerato                    0.3919
# Licenciatura                    0.2342
# Posgrado, maestria, doctorado   0.0631
# Primaria                        0.0766
# Secundaria                      0.2342
# Name: n_¿Cuál es el máximo nivel de estudios de tu mamá?, dtype: float64
#
#
#
# n_En caso de que tengas smartphone ¿Qué sistema operativo tiene?
#
# Android   0.8198
# iOS       0.1802
# Name: n_En caso de que tengas smartphone ¿Qué sistema operativo tiene?, dtype: float64
#
#
#
# n_¿Dónde vivirás mientras cursas tus estudios universitarios?
#
# En el mismo lugar   0.9279
# Otros               0.0721
# Name: n_¿Dónde vivirás mientras cursas tus estudios universitarios?, dtype: float64
#
#
#
# n_¿De qué forma financiarás tus estudios universitarios?
#
# Ayuda de mis padres u otros familiares      0.7387
# Becas UNAM                                  0.1622
# Recursos propios (trabajo, ahorros, etc.)   0.0991
# Name: n_¿De qué forma financiarás tus estudios universitarios?, dtype: float64
#
#
#
# n_¿En dónde cursaste el bachillerato?
#
# Escuela Nacional Preparatoria (UNAM)   0.6216
# Escuela privada                        0.0766
# Escuela pública                        0.2162
# Otro                                   0.0856
# Name: n_¿En dónde cursaste el bachillerato?, dtype: float64
#
#
#
# n_¿Cómo se llama la institución donde cursaste el bachillerato?
#
# CCH             0.0631
# CCH Naucalpan   0.0631
# Otros           0.8739
# Name: n_¿Cómo se llama la institución donde cursaste el bachillerato?, dtype: float64
#
#
#
# n_¿Recibiste alguna beca?
#
# No   0.2793
# Sí   0.7207
# Name: n_¿Recibiste alguna beca?, dtype: float64
#
#
#
# n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?
#
# Concurso de selección   0.1982
# Pase reglamentado       0.8018
# Name: n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?, dtype: float64
#
#
#
# n_Escoger ésta carrera fue...
#
# ❤️ Mi primera opción   0.9009
# 😊 Mi segunda opción    0.0991
# Name: n_Escoger ésta carrera fue..., dtype: float64
#
#
#
# n_Al escoger la FES Acatlán ésta fue:
#
# ☀️ Mi primera opción        0.6081
# ☔️ No quería este plantel   0.1757
# ⛅️ Mi segunda opción        0.2162
# Name: n_Al escoger la FES Acatlán ésta fue:, dtype: float64
#
#
#
# n_¿Cuándo tomaste la decisión de lo que querías estudiar?
#
# Al terminar el bachillerato       0.2162
# Antes del bachillerato            0.1126
# Durante el bachillerato           0.6171
# En otro momento o circunstancia   0.0541
# Name: n_¿Cuándo tomaste la decisión de lo que querías estudiar?, dtype: float64

# %%
unarias = [v for v in varn if df[v].value_counts().shape[0]==1]

# %%
varn = [v for v in varn if v not in unarias]

# %%
df[['¿Cuántas horas trabajas a la semana?']]
# Out:
#      ¿Cuántas horas trabajas a la semana?
# 0                                  0.0000
# 1                                     nan
# 2                                     nan
# 3                                  0.0000
# 4                                  0.0000
# ..                                    ...
# 217                                0.0000
# 218                                0.0000
# 219                                0.0000
# 220                                   nan
# 221                                5.0000
#
# [222 rows x 1 columns]

# %% [markdown]
# ## Discretización de variables continuas

# %%
miss, nomiss = df.loc[df[v].isnull()][[v]],df.loc[~df[v].isnull()][[v]]

# %%
miss[[v]].head()
# Out:
# Empty DataFrame
# Columns: [n_¿Cuándo tomaste la decisión de lo que querías estudiar?]
# Index: []

# %%
l = []
for v in varc:
    for st in ['uniform','quantile']:
        for k in range(2,6):
            kb = KBinsDiscretizer(n_bins=k,
                                  strategy=st,
                                  encode='ordinal')
            
            miss, nomiss = df.loc[df[v].isnull()][[v]],df.loc[~df[v].isnull()][[v]]    
            kb.fit(nomiss[[v]])
            nombre = f'd_{v}_{k}_{st[:3]}' 
            miss[nombre] = miss[v].fillna('MISSING')
            nomiss[nombre] = pd.cut(nomiss[v],bins=kb.bin_edges_[0],include_lowest=True).astype(str)
            l.append(pd.concat([nomiss[[nombre]],miss[[nombre]]]))
            if df[v].isnull().astype(int).cumsum()[221]>0:
                print(v)
                print(miss[nombre])
                print(nomiss[nombre])
# Out:
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_2_uni, Length: 103, dtype: object
# 0      (-0.001, 18.5]
# 3      (-0.001, 18.5]
# 4      (-0.001, 18.5]
# 5        (18.5, 37.0]
# 8      (-0.001, 18.5]
#             ...
# 215    (-0.001, 18.5]
# 217    (-0.001, 18.5]
# 218    (-0.001, 18.5]
# 219    (-0.001, 18.5]
# 221    (-0.001, 18.5]
# Name: d_¿Cuántas horas trabajas a la semana?_2_uni, Length: 119, dtype: object
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_3_uni, Length: 103, dtype: object
# 0      (-0.001, 12.333]
# 3      (-0.001, 12.333]
# 4      (-0.001, 12.333]
# 5      (12.333, 24.667]
# 8      (-0.001, 12.333]
#              ...
# 215    (-0.001, 12.333]
# 217    (-0.001, 12.333]
# 218    (-0.001, 12.333]
# 219    (-0.001, 12.333]
# 221    (-0.001, 12.333]
# Name: d_¿Cuántas horas trabajas a la semana?_3_uni, Length: 119, dtype: object
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_4_uni, Length: 103, dtype: object
# 0      (-0.001, 9.25]
# 3      (-0.001, 9.25]
# 4      (-0.001, 9.25]
# 5       (18.5, 27.75]
# 8      (-0.001, 9.25]
#             ...
# 215    (-0.001, 9.25]
# 217    (-0.001, 9.25]
# 218    (-0.001, 9.25]
# 219    (-0.001, 9.25]
# 221    (-0.001, 9.25]
# Name: d_¿Cuántas horas trabajas a la semana?_4_uni, Length: 119, dtype: object
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_5_uni, Length: 103, dtype: object
# 0      (-0.001, 7.4]
# 3      (-0.001, 7.4]
# 4      (-0.001, 7.4]
# 5       (14.8, 22.2]
# 8      (-0.001, 7.4]
#            ...
# 215    (-0.001, 7.4]
# 217    (-0.001, 7.4]
# 218    (-0.001, 7.4]
# 219    (-0.001, 7.4]
# 221    (-0.001, 7.4]
# Name: d_¿Cuántas horas trabajas a la semana?_5_uni, Length: 119, dtype: object
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_2_qua, Length: 103, dtype: object
# 0      (-0.001, 37.0]
# 3      (-0.001, 37.0]
# 4      (-0.001, 37.0]
# 5      (-0.001, 37.0]
# 8      (-0.001, 37.0]
#             ...
# 215    (-0.001, 37.0]
# 217    (-0.001, 37.0]
# 218    (-0.001, 37.0]
# 219    (-0.001, 37.0]
# 221    (-0.001, 37.0]
# Name: d_¿Cuántas horas trabajas a la semana?_2_qua, Length: 119, dtype: object
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_3_qua, Length: 103, dtype: object
# 0      (-0.001, 37.0]
# 3      (-0.001, 37.0]
# 4      (-0.001, 37.0]
# 5      (-0.001, 37.0]
# 8      (-0.001, 37.0]
#             ...
# 215    (-0.001, 37.0]
# 217    (-0.001, 37.0]
# 218    (-0.001, 37.0]
# 219    (-0.001, 37.0]
# 221    (-0.001, 37.0]
# Name: d_¿Cuántas horas trabajas a la semana?_3_qua, Length: 119, dtype: object
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_4_qua, Length: 103, dtype: object
# 0      (-0.001, 4.0]
# 3      (-0.001, 4.0]
# 4      (-0.001, 4.0]
# 5        (4.0, 37.0]
# 8      (-0.001, 4.0]
#            ...
# 215    (-0.001, 4.0]
# 217    (-0.001, 4.0]
# 218    (-0.001, 4.0]
# 219    (-0.001, 4.0]
# 221      (4.0, 37.0]
# Name: d_¿Cuántas horas trabajas a la semana?_4_qua, Length: 119, dtype: object
# ¿Cuántas horas trabajas a la semana?
# 1      MISSING
# 2      MISSING
# 6      MISSING
# 7      MISSING
# 9      MISSING
#         ...
# 208    MISSING
# 209    MISSING
# 210    MISSING
# 216    MISSING
# 220    MISSING
# Name: d_¿Cuántas horas trabajas a la semana?_5_qua, Length: 103, dtype: object
# 0      (-0.001, 8.0]
# 3      (-0.001, 8.0]
# 4      (-0.001, 8.0]
# 5        (8.0, 37.0]
# 8      (-0.001, 8.0]
#            ...
# 215    (-0.001, 8.0]
# 217    (-0.001, 8.0]
# 218    (-0.001, 8.0]
# 219    (-0.001, 8.0]
# 221    (-0.001, 8.0]
# Name: d_¿Cuántas horas trabajas a la semana?_5_qua, Length: 119, dtype: object

# %%
dfd = reduce(lambda x,y:pd.merge(x,y,left_index=True,right_index=True,how='outer'),l)

# %%
dfd.shape,df.shape
# Out:
# ((222, 128), (222, 103))

# %%
dfd[['d_¿Cuántas horas trabajas a la semana?_2_uni']].head()
# Out:
#   d_¿Cuántas horas trabajas a la semana?_2_uni
# 0                               (-0.001, 18.5]
# 1                                      MISSING
# 2                                      MISSING
# 3                               (-0.001, 18.5]
# 4                               (-0.001, 18.5]

# %% [markdown]
# ## Juntar discretas, continuas y target

# %%
df[[tgt]+varn]
# Out:
#                                  Carrera     n_Estado civil  \
# 0    Matemáticas Aplicadas y Computación          👤 Soltero
# 1    Matemáticas Aplicadas y Computación          👤 Soltero
# 2    Matemáticas Aplicadas y Computación          👤 Soltero
# 3    Matemáticas Aplicadas y Computación  👥 En una relación
# 4    Matemáticas Aplicadas y Computación          👤 Soltero
# ..                                   ...                ...
# 217                             Actuaria          👤 Soltero
# 218                             Actuaria          👤 Soltero
# 219                             Actuaria  👥 En una relación
# 220                             Actuaria          👤 Soltero
# 221                             Actuaria          👤 Soltero
#
#     n_¿Tienes alguna dificultad para? [👓 Ver] n_¿Dónde vives actualmente?  \
# 0                                          Si                        CDMX
# 1                                          Si            Estado de México
# 2                                          No            Estado de México
# 3                                          Si                        CDMX
# 4                                          Si                        CDMX
# ..                                        ...                         ...
# 217                                        No            Estado de México
# 218                                        Si            Estado de México
# 219                                        Si                        CDMX
# 220                                        No                        CDMX
# 221                                        Si                        CDMX
#
#     n_¿En qué delegación o municipio?  \
# 0                               Otros
# 1                           Naucalpan
# 2                               Otros
# 3                               Otros
# 4                               Otros
# ..                                ...
# 217                             Otros
# 218                             Otros
# 219                             Otros
# 220                             Otros
# 221                             Otros
#
#     n_¿Qué medio de transporte utilizas para llegar a la facultad?  \
# 0    Transporte público (metro, metrobus, micro, co...
# 1    Transporte público (metro, metrobus, micro, co...
# 2    Transporte público (metro, metrobus, micro, co...
# 3    Vehículo propio (Automóvil, motocicleta, moton...
# 4    Transporte público (metro, metrobus, micro, co...
# ..                                                 ...
# 217  Transporte público (metro, metrobus, micro, co...
# 218  Transporte público (metro, metrobus, micro, co...
# 219  Transporte público (metro, metrobus, micro, co...
# 220  Transporte público (metro, metrobus, micro, co...
# 221  Transporte público (metro, metrobus, micro, co...
#
#     n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?  \
# 0                                              Rentada
# 1    Ocupada sin pagar renta (incluye casa de famil...
# 2                                              Rentada
# 3                              Propia (ya esta pagada)
# 4                              Propia (ya esta pagada)
# ..                                                 ...
# 217                           Propia (se esta pagando)
# 218                            Propia (ya esta pagada)
# 219                           Propia (se esta pagando)
# 220                            Propia (ya esta pagada)
# 221                            Propia (ya esta pagada)
#
#     n_¿Con quién vives? (Puedes seleccionar más de una)  \
# 0                    👩🏽 Mamá, 👨🏽 Papá, 👦🏽👧🏽 Hermano(s)
# 1                                                Otros
# 2                             👩🏽 Mamá, 👦🏽👧🏽 Hermano(s)
# 3                                                Otros
# 4                                                Otros
# ..                                                 ...
# 217                                   👩🏽 Mamá, 👨🏽 Papá
# 218                  👩🏽 Mamá, 👨🏽 Papá, 👦🏽👧🏽 Hermano(s)
# 219                  👩🏽 Mamá, 👨🏽 Papá, 👦🏽👧🏽 Hermano(s)
# 220                  👩🏽 Mamá, 👨🏽 Papá, 👦🏽👧🏽 Hermano(s)
# 221                                              Otros
#
#     n_¿Cuál es el máximo nivel de estudios de tu papá?  \
# 0                                             Primaria
# 1                                         Bachillerato
# 2                                           Secundaria
# 3                                         Licenciatura
# 4                                         Bachillerato
# ..                                                 ...
# 217                                              Otros
# 218                                           Primaria
# 219                                       Bachillerato
# 220                                       Licenciatura
# 221                                       Bachillerato
#
#     n_¿Cuál es el máximo nivel de estudios de tu mamá?  \
# 0                                         Bachillerato
# 1                                         Licenciatura
# 2                                         Bachillerato
# 3                                         Bachillerato
# 4                                           Secundaria
# ..                                                 ...
# 217                                       Licenciatura
# 218                                           Primaria
# 219                                       Bachillerato
# 220                                       Licenciatura
# 221                                       Bachillerato
#
#     n_En caso de que tengas smartphone ¿Qué sistema operativo tiene?  \
# 0                                              Android
# 1                                              Android
# 2                                              Android
# 3                                                  iOS
# 4                                              Android
# ..                                                 ...
# 217                                                iOS
# 218                                            Android
# 219                                            Android
# 220                                            Android
# 221                                            Android
#
#     n_¿Dónde vivirás mientras cursas tus estudios universitarios?  \
# 0                                    En el mismo lugar
# 1                                    En el mismo lugar
# 2                                    En el mismo lugar
# 3                                    En el mismo lugar
# 4                                    En el mismo lugar
# ..                                                 ...
# 217                                  En el mismo lugar
# 218                                              Otros
# 219                                  En el mismo lugar
# 220                                  En el mismo lugar
# 221                                  En el mismo lugar
#
#     n_¿De qué forma financiarás tus estudios universitarios?  \
# 0               Ayuda de mis padres u otros familiares
# 1               Ayuda de mis padres u otros familiares
# 2               Ayuda de mis padres u otros familiares
# 3               Ayuda de mis padres u otros familiares
# 4               Ayuda de mis padres u otros familiares
# ..                                                 ...
# 217             Ayuda de mis padres u otros familiares
# 218             Ayuda de mis padres u otros familiares
# 219                                         Becas UNAM
# 220                                         Becas UNAM
# 221                                         Becas UNAM
#
#     n_¿En dónde cursaste el bachillerato?  \
# 0    Escuela Nacional Preparatoria (UNAM)
# 1    Escuela Nacional Preparatoria (UNAM)
# 2    Escuela Nacional Preparatoria (UNAM)
# 3    Escuela Nacional Preparatoria (UNAM)
# 4                         Escuela pública
# ..                                    ...
# 217  Escuela Nacional Preparatoria (UNAM)
# 218  Escuela Nacional Preparatoria (UNAM)
# 219  Escuela Nacional Preparatoria (UNAM)
# 220  Escuela Nacional Preparatoria (UNAM)
# 221  Escuela Nacional Preparatoria (UNAM)
#
#     n_¿Cómo se llama la institución donde cursaste el bachillerato?  \
# 0                                                Otros
# 1                                                  CCH
# 2                                                Otros
# 3                                                Otros
# 4                                                Otros
# ..                                                 ...
# 217                                              Otros
# 218                                              Otros
# 219                                              Otros
# 220                                              Otros
# 221                                              Otros
#
#     n_¿Recibiste alguna beca?  \
# 0                          Sí
# 1                          Sí
# 2                          Sí
# 3                          Sí
# 4                          Sí
# ..                        ...
# 217                        No
# 218                        Sí
# 219                        Sí
# 220                        Sí
# 221                        Sí
#
#     n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?  \
# 0                                    Pase reglamentado
# 1                                    Pase reglamentado
# 2                                    Pase reglamentado
# 3                                    Pase reglamentado
# 4                                Concurso de selección
# ..                                                 ...
# 217                                  Pase reglamentado
# 218                                  Pase reglamentado
# 219                                  Pase reglamentado
# 220                                  Pase reglamentado
# 221                                  Pase reglamentado
#
#     n_Escoger ésta carrera fue... n_Al escoger la FES Acatlán ésta fue:  \
# 0            ❤️ Mi primera opción             ☔️ No quería este plantel
# 1             😊 Mi segunda opción                  ☀️ Mi primera opción
# 2            ❤️ Mi primera opción             ☔️ No quería este plantel
# 3            ❤️ Mi primera opción                  ☀️ Mi primera opción
# 4            ❤️ Mi primera opción                  ☀️ Mi primera opción
# ..                            ...                                   ...
# 217          ❤️ Mi primera opción                  ☀️ Mi primera opción
# 218          ❤️ Mi primera opción             ☔️ No quería este plantel
# 219          ❤️ Mi primera opción             ☔️ No quería este plantel
# 220          ❤️ Mi primera opción                  ⛅️ Mi segunda opción
# 221          ❤️ Mi primera opción                  ⛅️ Mi segunda opción
#
#     n_¿Cuándo tomaste la decisión de lo que querías estudiar?
# 0                              Durante el bachillerato
# 1                              Durante el bachillerato
# 2                              Durante el bachillerato
# 3                              Durante el bachillerato
# 4                          Al terminar el bachillerato
# ..                                                 ...
# 217                            Durante el bachillerato
# 218                            Durante el bachillerato
# 219                            Durante el bachillerato
# 220                            Durante el bachillerato
# 221                             Antes del bachillerato
#
# [222 rows x 20 columns]

# %%
df = df[[tgt]+varn].merge(dfd,left_index=True,right_index=True,how='outer')

# %%
df[tgt] = (df[tgt] =='Actuaria').astype(int)

# %%
df[tgt].value_counts(1)
# Out:
# 1   0.6802
# 0   0.3198
# Name: Carrera, dtype: float64

# %%
df.head()
# Out:
#    Carrera     n_Estado civil n_¿Tienes alguna dificultad para? [👓 Ver]  \
# 0        0          👤 Soltero                                        Si
# 1        0          👤 Soltero                                        Si
# 2        0          👤 Soltero                                        No
# 3        0  👥 En una relación                                        Si
# 4        0          👤 Soltero                                        Si
#
#   n_¿Dónde vives actualmente? n_¿En qué delegación o municipio?  \
# 0                        CDMX                             Otros
# 1            Estado de México                         Naucalpan
# 2            Estado de México                             Otros
# 3                        CDMX                             Otros
# 4                        CDMX                             Otros
#
#   n_¿Qué medio de transporte utilizas para llegar a la facultad?  \
# 0  Transporte público (metro, metrobus, micro, co...
# 1  Transporte público (metro, metrobus, micro, co...
# 2  Transporte público (metro, metrobus, micro, co...
# 3  Vehículo propio (Automóvil, motocicleta, moton...
# 4  Transporte público (metro, metrobus, micro, co...
#
#   n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?  \
# 0                                            Rentada
# 1  Ocupada sin pagar renta (incluye casa de famil...
# 2                                            Rentada
# 3                            Propia (ya esta pagada)
# 4                            Propia (ya esta pagada)
#
#   n_¿Con quién vives? (Puedes seleccionar más de una)  \
# 0                  👩🏽 Mamá, 👨🏽 Papá, 👦🏽👧🏽 Hermano(s)
# 1                                              Otros
# 2                           👩🏽 Mamá, 👦🏽👧🏽 Hermano(s)
# 3                                              Otros
# 4                                              Otros
#
#   n_¿Cuál es el máximo nivel de estudios de tu papá?  \
# 0                                           Primaria
# 1                                       Bachillerato
# 2                                         Secundaria
# 3                                       Licenciatura
# 4                                       Bachillerato
#
#   n_¿Cuál es el máximo nivel de estudios de tu mamá?  \
# 0                                       Bachillerato
# 1                                       Licenciatura
# 2                                       Bachillerato
# 3                                       Bachillerato
# 4                                         Secundaria
#
#   n_En caso de que tengas smartphone ¿Qué sistema operativo tiene?  \
# 0                                            Android
# 1                                            Android
# 2                                            Android
# 3                                                iOS
# 4                                            Android
#
#   n_¿Dónde vivirás mientras cursas tus estudios universitarios?  \
# 0                                  En el mismo lugar
# 1                                  En el mismo lugar
# 2                                  En el mismo lugar
# 3                                  En el mismo lugar
# 4                                  En el mismo lugar
#
#   n_¿De qué forma financiarás tus estudios universitarios?  \
# 0             Ayuda de mis padres u otros familiares
# 1             Ayuda de mis padres u otros familiares
# 2             Ayuda de mis padres u otros familiares
# 3             Ayuda de mis padres u otros familiares
# 4             Ayuda de mis padres u otros familiares
#
#   n_¿En dónde cursaste el bachillerato?  \
# 0  Escuela Nacional Preparatoria (UNAM)
# 1  Escuela Nacional Preparatoria (UNAM)
# 2  Escuela Nacional Preparatoria (UNAM)
# 3  Escuela Nacional Preparatoria (UNAM)
# 4                       Escuela pública
#
#   n_¿Cómo se llama la institución donde cursaste el bachillerato?  \
# 0                                              Otros
# 1                                                CCH
# 2                                              Otros
# 3                                              Otros
# 4                                              Otros
#
#   n_¿Recibiste alguna beca?  \
# 0                        Sí
# 1                        Sí
# 2                        Sí
# 3                        Sí
# 4                        Sí
#
#   n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?  \
# 0                                  Pase reglamentado
# 1                                  Pase reglamentado
# 2                                  Pase reglamentado
# 3                                  Pase reglamentado
# 4                              Concurso de selección
#
#   n_Escoger ésta carrera fue... n_Al escoger la FES Acatlán ésta fue:  \
# 0          ❤️ Mi primera opción             ☔️ No quería este plantel
# 1           😊 Mi segunda opción                  ☀️ Mi primera opción
# 2          ❤️ Mi primera opción             ☔️ No quería este plantel
# 3          ❤️ Mi primera opción                  ☀️ Mi primera opción
# 4          ❤️ Mi primera opción                  ☀️ Mi primera opción
#
#   n_¿Cuándo tomaste la decisión de lo que querías estudiar?  d_Edad 🎂_2_uni  \
# 0                            Durante el bachillerato         (16.999, 26.0]
# 1                            Durante el bachillerato         (16.999, 26.0]
# 2                            Durante el bachillerato         (16.999, 26.0]
# 3                            Durante el bachillerato         (16.999, 26.0]
# 4                        Al terminar el bachillerato         (16.999, 26.0]
#
#    d_Edad 🎂_3_uni  d_Edad 🎂_4_uni  d_Edad 🎂_5_uni  d_Edad 🎂_2_qua  \
# 0  (16.999, 23.0]  (16.999, 21.5]  (16.999, 20.6]  (16.999, 18.0]
# 1  (16.999, 23.0]  (16.999, 21.5]  (16.999, 20.6]  (16.999, 18.0]
# 2  (16.999, 23.0]  (16.999, 21.5]  (16.999, 20.6]  (16.999, 18.0]
# 3  (16.999, 23.0]  (16.999, 21.5]  (16.999, 20.6]  (16.999, 18.0]
# 4  (16.999, 23.0]  (16.999, 21.5]  (16.999, 20.6]    (18.0, 35.0]
#
#    d_Edad 🎂_3_qua  d_Edad 🎂_4_qua  d_Edad 🎂_5_qua  \
# 0  (16.999, 18.0]  (16.999, 18.0]  (16.999, 18.0]
# 1  (16.999, 18.0]  (16.999, 18.0]  (16.999, 18.0]
# 2  (16.999, 18.0]  (16.999, 18.0]  (16.999, 18.0]
# 3  (16.999, 18.0]  (16.999, 18.0]  (16.999, 18.0]
# 4    (18.0, 35.0]    (18.0, 19.0]    (18.0, 19.0]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_2_uni  \
# 0                                     (0.999, 120.5]
# 1                                     (0.999, 120.5]
# 2                                     (120.5, 240.0]
# 3                                     (0.999, 120.5]
# 4                                     (120.5, 240.0]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_3_uni  \
# 0                                  (80.667, 160.333]
# 1                                    (0.999, 80.667]
# 2                                  (80.667, 160.333]
# 3                                    (0.999, 80.667]
# 4                                  (80.667, 160.333]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_4_uni  \
# 0                                     (60.75, 120.5]
# 1                                     (0.999, 60.75]
# 2                                    (120.5, 180.25]
# 3                                     (0.999, 60.75]
# 4                                    (120.5, 180.25]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_5_uni  \
# 0                                      (96.6, 144.4]
# 1                                       (48.8, 96.6]
# 2                                      (96.6, 144.4]
# 3                                      (0.999, 48.8]
# 4                                     (144.4, 192.2]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_2_qua  \
# 0                                      (90.0, 240.0]
# 1                                      (0.999, 90.0]
# 2                                      (90.0, 240.0]
# 3                                      (0.999, 90.0]
# 4                                      (90.0, 240.0]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_3_qua  \
# 0                                   (101.667, 240.0]
# 1                                      (0.999, 60.0]
# 2                                   (101.667, 240.0]
# 3                                      (0.999, 60.0]
# 4                                   (101.667, 240.0]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_4_qua  \
# 0                                      (90.0, 120.0]
# 1                                       (45.0, 90.0]
# 2                                     (120.0, 240.0]
# 3                                      (0.999, 45.0]
# 4                                     (120.0, 240.0]
#
#   d_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_5_qua  \
# 0                                      (98.0, 120.0]
# 1                                       (40.0, 64.0]
# 2                                     (120.0, 240.0]
# 3                                      (0.999, 40.0]
# 4                                     (120.0, 240.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_2_uni  \
# 0                                       (0.999, 6.5]
# 1                                       (0.999, 6.5]
# 2                                       (0.999, 6.5]
# 3                                       (0.999, 6.5]
# 4                                        (6.5, 12.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_3_uni  \
# 0                                     (4.667, 8.333]
# 1                                     (4.667, 8.333]
# 2                                     (0.999, 4.667]
# 3                                     (0.999, 4.667]
# 4                                      (8.333, 12.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_4_uni  \
# 0                                        (3.75, 6.5]
# 1                                        (3.75, 6.5]
# 2                                      (0.999, 3.75]
# 3                                        (3.75, 6.5]
# 4                                       (9.25, 12.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_uni  \
# 0                                         (5.4, 7.6]
# 1                                         (5.4, 7.6]
# 2                                       (0.999, 3.2]
# 3                                         (3.2, 5.4]
# 4                                        (9.8, 12.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_2_qua  \
# 0                                        (4.0, 12.0]
# 1                                        (4.0, 12.0]
# 2                                       (0.999, 4.0]
# 3                                       (0.999, 4.0]
# 4                                        (4.0, 12.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_3_qua  \
# 0                                        (5.0, 12.0]
# 1                                        (5.0, 12.0]
# 2                                       (0.999, 4.0]
# 3                                       (0.999, 4.0]
# 4                                        (5.0, 12.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_4_qua  \
# 0                                        (5.0, 12.0]
# 1                                        (5.0, 12.0]
# 2                                       (0.999, 4.0]
# 3                                       (0.999, 4.0]
# 4                                        (5.0, 12.0]
#
#   d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua  \
# 0                                         (5.0, 6.0]
# 1                                         (5.0, 6.0]
# 2                                       (0.999, 3.0]
# 3                                         (3.0, 4.0]
# 4                                        (6.0, 12.0]
#
#   d_¿Cuántos son hombres?_2_uni d_¿Cuántos son hombres?_3_uni  \
# 0                    (3.5, 7.0]                (2.333, 4.667]
# 1                 (-0.001, 3.5]                (2.333, 4.667]
# 2                 (-0.001, 3.5]               (-0.001, 2.333]
# 3                 (-0.001, 3.5]               (-0.001, 2.333]
# 4                 (-0.001, 3.5]               (-0.001, 2.333]
#
#   d_¿Cuántos son hombres?_4_uni d_¿Cuántos son hombres?_5_uni  \
# 0                   (3.5, 5.25]                    (2.8, 4.2]
# 1                   (1.75, 3.5]                    (2.8, 4.2]
# 2                (-0.001, 1.75]                 (-0.001, 1.4]
# 3                   (1.75, 3.5]                    (1.4, 2.8]
# 4                   (1.75, 3.5]                    (1.4, 2.8]
#
#   d_¿Cuántos son hombres?_2_qua d_¿Cuántos son hombres?_3_qua  \
# 0                    (2.0, 7.0]                    (3.0, 7.0]
# 1                    (2.0, 7.0]                    (2.0, 3.0]
# 2                 (-0.001, 2.0]                 (-0.001, 2.0]
# 3                 (-0.001, 2.0]                 (-0.001, 2.0]
# 4                 (-0.001, 2.0]                 (-0.001, 2.0]
#
#   d_¿Cuántos son hombres?_4_qua d_¿Cuántos son hombres?_5_qua  \
# 0                    (3.0, 7.0]                    (3.0, 7.0]
# 1                    (2.0, 3.0]                    (2.0, 3.0]
# 2                 (-0.001, 1.0]                 (-0.001, 1.0]
# 3                    (1.0, 2.0]                    (1.0, 2.0]
# 4                    (1.0, 2.0]                    (1.0, 2.0]
#
#   d_¿Cuántas son mujeres?_2_uni d_¿Cuántas son mujeres?_3_uni  \
# 0                 (-0.001, 4.5]                 (-0.001, 3.0]
# 1                 (-0.001, 4.5]                 (-0.001, 3.0]
# 2                 (-0.001, 4.5]                 (-0.001, 3.0]
# 3                 (-0.001, 4.5]                 (-0.001, 3.0]
# 4                    (4.5, 9.0]                    (6.0, 9.0]
#
#   d_¿Cuántas son mujeres?_4_uni d_¿Cuántas son mujeres?_5_uni  \
# 0                (-0.001, 2.25]                    (1.8, 3.6]
# 1                   (2.25, 4.5]                    (1.8, 3.6]
# 2                (-0.001, 2.25]                    (1.8, 3.6]
# 3                (-0.001, 2.25]                    (1.8, 3.6]
# 4                   (6.75, 9.0]                    (7.2, 9.0]
#
#   d_¿Cuántas son mujeres?_2_qua d_¿Cuántas son mujeres?_3_qua  \
# 0                 (-0.001, 2.0]                 (-0.001, 2.0]
# 1                    (2.0, 9.0]                    (2.0, 3.0]
# 2                 (-0.001, 2.0]                 (-0.001, 2.0]
# 3                 (-0.001, 2.0]                 (-0.001, 2.0]
# 4                    (2.0, 9.0]                    (3.0, 9.0]
#
#   d_¿Cuántas son mujeres?_4_qua d_¿Cuántas son mujeres?_5_qua  \
# 0                 (-0.001, 2.0]                 (-0.001, 2.0]
# 1                    (2.0, 3.0]                    (2.0, 3.0]
# 2                 (-0.001, 2.0]                 (-0.001, 2.0]
# 3                 (-0.001, 2.0]                 (-0.001, 2.0]
# 4                    (3.0, 9.0]                    (3.0, 9.0]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_2_uni  \
# 0                                     (-0.001, 17.5]
# 1                                     (-0.001, 17.5]
# 2                                     (-0.001, 17.5]
# 3                                       (17.5, 35.0]
# 4                                       (17.5, 35.0]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_3_uni  \
# 0                                   (-0.001, 11.667]
# 1                                   (-0.001, 11.667]
# 2                                   (-0.001, 11.667]
# 3                                   (11.667, 23.333]
# 4                                   (11.667, 23.333]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_4_uni  \
# 0                                     (-0.001, 8.75]
# 1                                     (-0.001, 8.75]
# 2                                     (-0.001, 8.75]
# 3                                      (17.5, 26.25]
# 4                                      (17.5, 26.25]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_5_uni  \
# 0                                      (-0.001, 7.0]
# 1                                      (-0.001, 7.0]
# 2                                      (-0.001, 7.0]
# 3                                       (14.0, 21.0]
# 4                                       (14.0, 21.0]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_2_qua  \
# 0                                     (-0.001, 16.0]
# 1                                     (-0.001, 16.0]
# 2                                     (-0.001, 16.0]
# 3                                       (16.0, 35.0]
# 4                                       (16.0, 35.0]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_3_qua  \
# 0                                      (-0.001, 9.0]
# 1                                      (-0.001, 9.0]
# 2                                      (-0.001, 9.0]
# 3                                        (9.0, 18.0]
# 4                                       (18.0, 35.0]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_4_qua  \
# 0                                      (-0.001, 6.0]
# 1                                      (-0.001, 6.0]
# 2                                      (-0.001, 6.0]
# 3                                       (16.0, 18.0]
# 4                                       (18.0, 35.0]
#
#   d_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua  \
# 0                                      (-0.001, 5.0]
# 1                                      (-0.001, 5.0]
# 2                                      (-0.001, 5.0]
# 3                                       (17.0, 18.0]
# 4                                       (18.0, 35.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_2_uni  \
# 0                                       (0.999, 3.5]
# 1                                       (0.999, 3.5]
# 2                                       (0.999, 3.5]
# 3                                         (3.5, 6.0]
# 4                                         (3.5, 6.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_3_uni  \
# 0                                     (0.999, 2.667]
# 1                                     (2.667, 4.333]
# 2                                     (0.999, 2.667]
# 3                                       (4.333, 6.0]
# 4                                       (4.333, 6.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_4_uni  \
# 0                                      (0.999, 2.25]
# 1                                        (2.25, 3.5]
# 2                                      (0.999, 2.25]
# 3                                        (4.75, 6.0]
# 4                                        (4.75, 6.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_5_uni  \
# 0                                       (0.999, 2.0]
# 1                                         (2.0, 3.0]
# 2                                       (0.999, 2.0]
# 3                                         (4.0, 5.0]
# 4                                         (5.0, 6.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_2_qua  \
# 0                                       (0.999, 3.0]
# 1                                       (0.999, 3.0]
# 2                                       (0.999, 3.0]
# 3                                         (3.0, 6.0]
# 4                                         (3.0, 6.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_3_qua  \
# 0                                       (0.999, 2.0]
# 1                                         (2.0, 3.0]
# 2                                       (0.999, 2.0]
# 3                                         (3.0, 6.0]
# 4                                         (3.0, 6.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_4_qua  \
# 0                                       (0.999, 2.0]
# 1                                         (2.0, 3.0]
# 2                                       (0.999, 2.0]
# 3                                         (3.0, 6.0]
# 4                                         (3.0, 6.0]
#
#   d_¿Cuántos cuartos para dormir tiene tu vivienda?_5_qua  \
# 0                                       (0.999, 2.0]
# 1                                         (2.0, 3.0]
# 2                                       (0.999, 2.0]
# 3                                         (4.0, 6.0]
# 4                                         (4.0, 6.0]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_2_uni  \
# 0                                      (-0.001, 3.5]
# 1                                      (-0.001, 3.5]
# 2                                      (-0.001, 3.5]
# 3                                      (-0.001, 3.5]
# 4                                      (-0.001, 3.5]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_3_uni  \
# 0                                    (-0.001, 2.333]
# 1                                    (-0.001, 2.333]
# 2                                    (-0.001, 2.333]
# 3                                    (-0.001, 2.333]
# 4                                    (-0.001, 2.333]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_4_uni  \
# 0                                     (-0.001, 1.75]
# 1                                        (1.75, 3.5]
# 2                                     (-0.001, 1.75]
# 3                                     (-0.001, 1.75]
# 4                                     (-0.001, 1.75]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_5_uni  \
# 0                                      (-0.001, 1.4]
# 1                                         (1.4, 2.8]
# 2                                      (-0.001, 1.4]
# 3                                      (-0.001, 1.4]
# 4                                      (-0.001, 1.4]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_2_qua  \
# 0                                      (-0.001, 1.0]
# 1                                         (1.0, 7.0]
# 2                                      (-0.001, 1.0]
# 3                                      (-0.001, 1.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_3_qua  \
# 0                                      (-0.001, 1.0]
# 1                                         (1.0, 7.0]
# 2                                      (-0.001, 1.0]
# 3                                      (-0.001, 1.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_4_qua  \
# 0                                      (-0.001, 1.0]
# 1                                         (1.0, 7.0]
# 2                                      (-0.001, 1.0]
# 3                                      (-0.001, 1.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_5_qua  \
# 0                                      (-0.001, 1.0]
# 1                                         (1.0, 2.0]
# 2                                      (-0.001, 1.0]
# 3                                      (-0.001, 1.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántas horas trabajas a la semana?_2_uni  \
# 0                               (-0.001, 18.5]
# 1                                      MISSING
# 2                                      MISSING
# 3                               (-0.001, 18.5]
# 4                               (-0.001, 18.5]
#
#   d_¿Cuántas horas trabajas a la semana?_3_uni  \
# 0                             (-0.001, 12.333]
# 1                                      MISSING
# 2                                      MISSING
# 3                             (-0.001, 12.333]
# 4                             (-0.001, 12.333]
#
#   d_¿Cuántas horas trabajas a la semana?_4_uni  \
# 0                               (-0.001, 9.25]
# 1                                      MISSING
# 2                                      MISSING
# 3                               (-0.001, 9.25]
# 4                               (-0.001, 9.25]
#
#   d_¿Cuántas horas trabajas a la semana?_5_uni  \
# 0                                (-0.001, 7.4]
# 1                                      MISSING
# 2                                      MISSING
# 3                                (-0.001, 7.4]
# 4                                (-0.001, 7.4]
#
#   d_¿Cuántas horas trabajas a la semana?_2_qua  \
# 0                               (-0.001, 37.0]
# 1                                      MISSING
# 2                                      MISSING
# 3                               (-0.001, 37.0]
# 4                               (-0.001, 37.0]
#
#   d_¿Cuántas horas trabajas a la semana?_3_qua  \
# 0                               (-0.001, 37.0]
# 1                                      MISSING
# 2                                      MISSING
# 3                               (-0.001, 37.0]
# 4                               (-0.001, 37.0]
#
#   d_¿Cuántas horas trabajas a la semana?_4_qua  \
# 0                                (-0.001, 4.0]
# 1                                      MISSING
# 2                                      MISSING
# 3                                (-0.001, 4.0]
# 4                                (-0.001, 4.0]
#
#   d_¿Cuántas horas trabajas a la semana?_5_qua  \
# 0                                (-0.001, 8.0]
# 1                                      MISSING
# 2                                      MISSING
# 3                                (-0.001, 8.0]
# 4                                (-0.001, 8.0]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_2_uni  \
# 0                                       (6.999, 8.5]
# 1                                       (6.999, 8.5]
# 2                                       (6.999, 8.5]
# 3                                       (6.999, 8.5]
# 4                                       (6.999, 8.5]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_3_uni  \
# 0                                       (6.999, 8.0]
# 1                                       (6.999, 8.0]
# 2                                         (8.0, 9.0]
# 3                                         (8.0, 9.0]
# 4                                         (8.0, 9.0]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_4_uni  \
# 0                                      (6.999, 7.75]
# 1                                        (7.75, 8.5]
# 2                                        (7.75, 8.5]
# 3                                        (7.75, 8.5]
# 4                                        (7.75, 8.5]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_5_uni  \
# 0                                       (6.999, 7.6]
# 1                                         (7.6, 8.2]
# 2                                         (8.2, 8.8]
# 3                                         (8.2, 8.8]
# 4                                         (8.2, 8.8]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_2_qua  \
# 0                                     (6.999, 8.815]
# 1                                     (6.999, 8.815]
# 2                                     (6.999, 8.815]
# 3                                     (6.999, 8.815]
# 4                                     (6.999, 8.815]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_3_qua  \
# 0                                       (6.999, 8.7]
# 1                                       (6.999, 8.7]
# 2                                       (6.999, 8.7]
# 3                                       (6.999, 8.7]
# 4                                       (6.999, 8.7]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_4_qua  \
# 0                                       (6.999, 8.5]
# 1                                       (6.999, 8.5]
# 2                                       (6.999, 8.5]
# 3                                       (6.999, 8.5]
# 4                                       (6.999, 8.5]
#
#   d_¿Qué promedio obtuviste en el bachillerato?_5_qua  \
# 0                                       (6.999, 8.3]
# 1                                       (6.999, 8.3]
# 2                                        (8.3, 8.79]
# 3                                        (8.3, 8.79]
# 4                                        (8.3, 8.79]
#
#   d_¿En cuántos años lo terminaste?_2_uni  \
# 0                            (0.999, 3.0]
# 1                            (0.999, 3.0]
# 2                            (0.999, 3.0]
# 3                            (0.999, 3.0]
# 4                            (0.999, 3.0]
#
#   d_¿En cuántos años lo terminaste?_3_uni  \
# 0                          (2.333, 3.667]
# 1                          (2.333, 3.667]
# 2                          (2.333, 3.667]
# 3                          (2.333, 3.667]
# 4                          (2.333, 3.667]
#
#   d_¿En cuántos años lo terminaste?_4_uni  \
# 0                              (2.0, 3.0]
# 1                              (2.0, 3.0]
# 2                              (2.0, 3.0]
# 3                              (2.0, 3.0]
# 4                              (2.0, 3.0]
#
#   d_¿En cuántos años lo terminaste?_5_uni  \
# 0                              (2.6, 3.4]
# 1                              (2.6, 3.4]
# 2                              (2.6, 3.4]
# 3                              (2.6, 3.4]
# 4                              (2.6, 3.4]
#
#   d_¿En cuántos años lo terminaste?_2_qua  \
# 0                            (0.999, 3.0]
# 1                            (0.999, 3.0]
# 2                            (0.999, 3.0]
# 3                            (0.999, 3.0]
# 4                            (0.999, 3.0]
#
#   d_¿En cuántos años lo terminaste?_3_qua  \
# 0                            (0.999, 3.0]
# 1                            (0.999, 3.0]
# 2                            (0.999, 3.0]
# 3                            (0.999, 3.0]
# 4                            (0.999, 3.0]
#
#   d_¿En cuántos años lo terminaste?_4_qua  \
# 0                            (0.999, 3.0]
# 1                            (0.999, 3.0]
# 2                            (0.999, 3.0]
# 3                            (0.999, 3.0]
# 4                            (0.999, 3.0]
#
#   d_¿En cuántos años lo terminaste?_5_qua  \
# 0                            (0.999, 3.0]
# 1                            (0.999, 3.0]
# 2                            (0.999, 3.0]
# 3                            (0.999, 3.0]
# 4                            (0.999, 3.0]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_2_uni  \
# 0                                (1000.999, 50500.5]
# 1                                (1000.999, 50500.5]
# 2                                (1000.999, 50500.5]
# 3                                (1000.999, 50500.5]
# 4                                (1000.999, 50500.5]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_3_uni  \
# 0                              (1000.999, 34000.667]
# 1                              (1000.999, 34000.667]
# 2                              (1000.999, 34000.667]
# 3                             (34000.667, 67000.333]
# 4                              (1000.999, 34000.667]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_4_uni  \
# 0                               (1000.999, 25750.75]
# 1                               (1000.999, 25750.75]
# 2                               (1000.999, 25750.75]
# 3                                (25750.75, 50500.5]
# 4                               (1000.999, 25750.75]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_5_uni  \
# 0                                (1000.999, 20800.8]
# 1                                (1000.999, 20800.8]
# 2                                (1000.999, 20800.8]
# 3                                 (20800.8, 40600.6]
# 4                                (1000.999, 20800.8]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_2_qua  \
# 0                                 (1000.999, 7400.0]
# 1                                 (1000.999, 7400.0]
# 2                                 (7400.0, 100000.0]
# 3                                 (7400.0, 100000.0]
# 4                                 (1000.999, 7400.0]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_3_qua  \
# 0                                 (1000.999, 5000.0]
# 1                                 (1000.999, 5000.0]
# 2                                  (5000.0, 10000.0]
# 3                                (10000.0, 100000.0]
# 4                                 (1000.999, 5000.0]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_4_qua  \
# 0                                 (1000.999, 4000.0]
# 1                                   (4000.0, 7400.0]
# 2                                  (7400.0, 12000.0]
# 3                                (12000.0, 100000.0]
# 4                                 (1000.999, 4000.0]
#
#   d_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_5_qua  \
# 0                                   (3500.0, 6000.0]
# 1                                   (3500.0, 6000.0]
# 2                                   (6000.0, 8500.0]
# 3                                (15000.0, 100000.0]
# 4                                   (3500.0, 6000.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_2_uni  \
# 0                                      (-0.001, 3.0]
# 1                                      (-0.001, 3.0]
# 2                                      (-0.001, 3.0]
# 3                                      (-0.001, 3.0]
# 4                                      (-0.001, 3.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_3_uni  \
# 0                                      (-0.001, 2.0]
# 1                                      (-0.001, 2.0]
# 2                                      (-0.001, 2.0]
# 3                                      (-0.001, 2.0]
# 4                                      (-0.001, 2.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_4_uni  \
# 0                                      (-0.001, 1.5]
# 1                                      (-0.001, 1.5]
# 2                                      (-0.001, 1.5]
# 3                                      (-0.001, 1.5]
# 4                                      (-0.001, 1.5]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_5_uni  \
# 0                                      (-0.001, 1.2]
# 1                                      (-0.001, 1.2]
# 2                                      (-0.001, 1.2]
# 3                                      (-0.001, 1.2]
# 4                                      (-0.001, 1.2]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_2_qua  \
# 0                                      (-0.001, 1.0]
# 1                                      (-0.001, 1.0]
# 2                                      (-0.001, 1.0]
# 3                                      (-0.001, 1.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_3_qua  \
# 0                                      (-0.001, 2.0]
# 1                                      (-0.001, 2.0]
# 2                                      (-0.001, 2.0]
# 3                                      (-0.001, 2.0]
# 4                                      (-0.001, 2.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_4_qua  \
# 0                                      (-0.001, 1.0]
# 1                                      (-0.001, 1.0]
# 2                                      (-0.001, 1.0]
# 3                                      (-0.001, 1.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_5_qua  \
# 0                                      (-0.001, 1.0]
# 1                                      (-0.001, 1.0]
# 2                                      (-0.001, 1.0]
# 3                                      (-0.001, 1.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_2_uni  \
# 0                                      (-0.001, 3.5]
# 1                                      (-0.001, 3.5]
# 2                                      (-0.001, 3.5]
# 3                                      (-0.001, 3.5]
# 4                                      (-0.001, 3.5]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_3_uni  \
# 0                                    (-0.001, 2.333]
# 1                                    (-0.001, 2.333]
# 2                                    (-0.001, 2.333]
# 3                                    (-0.001, 2.333]
# 4                                    (-0.001, 2.333]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_4_uni  \
# 0                                     (-0.001, 1.75]
# 1                                     (-0.001, 1.75]
# 2                                     (-0.001, 1.75]
# 3                                     (-0.001, 1.75]
# ...
# 1                                      (-0.001, 3.5]
# 2                                      (-0.001, 3.5]
# 3                                      (-0.001, 3.5]
# 4                                      (-0.001, 3.5]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_3_uni  \
# 0                                    (-0.001, 2.333]
# 1                                    (-0.001, 2.333]
# 2                                    (-0.001, 2.333]
# 3                                    (-0.001, 2.333]
# 4                                    (-0.001, 2.333]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_4_uni  \
# 0                                     (-0.001, 1.75]
# 1                                     (-0.001, 1.75]
# 2                                     (-0.001, 1.75]
# 3                                        (1.75, 3.5]
# 4                                     (-0.001, 1.75]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_5_uni  \
# 0                                      (-0.001, 1.4]
# 1                                      (-0.001, 1.4]
# 2                                      (-0.001, 1.4]
# 3                                         (1.4, 2.8]
# 4                                      (-0.001, 1.4]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_2_qua  \
# 0                                      (-0.001, 1.0]
# 1                                      (-0.001, 1.0]
# 2                                      (-0.001, 1.0]
# 3                                         (1.0, 7.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_3_qua  \
# 0                                      (-0.001, 1.0]
# 1                                      (-0.001, 1.0]
# 2                                      (-0.001, 1.0]
# 3                                         (1.0, 2.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_4_qua  \
# 0                                      (-0.001, 1.0]
# 1                                      (-0.001, 1.0]
# 2                                      (-0.001, 1.0]
# 3                                         (1.0, 2.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_5_qua  \
# 0                                      (-0.001, 1.0]
# 1                                      (-0.001, 1.0]
# 2                                      (-0.001, 1.0]
# 3                                         (1.0, 2.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_2_uni  \
# 0                                      (-0.001, 3.5]
# 1                                      (-0.001, 3.5]
# 2                                         (3.5, 7.0]
# 3                                         (3.5, 7.0]
# 4                                      (-0.001, 3.5]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_3_uni  \
# 0                                    (-0.001, 2.333]
# 1                                    (-0.001, 2.333]
# 2                                       (4.667, 7.0]
# 3                                       (4.667, 7.0]
# 4                                    (-0.001, 2.333]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_4_uni  \
# 0                                        (1.75, 3.5]
# 1                                        (1.75, 3.5]
# 2                                        (5.25, 7.0]
# 3                                        (3.5, 5.25]
# 4                                     (-0.001, 1.75]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_uni  \
# 0                                         (1.4, 2.8]
# 1                                         (1.4, 2.8]
# 2                                         (5.6, 7.0]
# 3                                         (4.2, 5.6]
# 4                                      (-0.001, 1.4]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_2_qua  \
# 0                                      (-0.001, 2.0]
# 1                                      (-0.001, 2.0]
# 2                                         (2.0, 7.0]
# 3                                         (2.0, 7.0]
# 4                                      (-0.001, 2.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_3_qua  \
# 0                                         (1.0, 3.0]
# 1                                         (1.0, 3.0]
# 2                                         (3.0, 7.0]
# 3                                         (3.0, 7.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_4_qua  \
# 0                                         (1.0, 2.0]
# 1                                         (1.0, 2.0]
# 2                                         (4.0, 7.0]
# 3                                         (4.0, 7.0]
# 4                                      (-0.001, 1.0]
#
#   d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua
# 0                                         (1.0, 2.0]
# 1                                         (1.0, 2.0]
# 2                                         (5.0, 7.0]
# 3                                         (3.0, 5.0]
# 4                                      (-0.001, 1.0]

# %% [markdown]
# ## Calcular IV

# %%
v = 'n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?'

# %%
def iv(df,v,tgt):
    aux = df[[v,tgt]].assign(n=1)
    aux = aux.pivot_table(index=v,
                    columns=tgt,
                    values='n',
                    fill_value=0,
                    aggfunc='sum')
    for i in range(2):
        aux[i]/=aux[i].sum()
    aux['woe'] = np.log(aux[0]/aux[1])
    aux['iv'] = (aux[0]-aux[1])*aux['woe']
    return v,aux['iv'].sum()

# %%
iv(df,v,tgt) # Esta variable no tiene mucha información
# Out:
# ('n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?',
#  0.004659679679024691)

# %%
print("""<0.1 Débil
0.1-0.3 Media
0.3-0.5 Fuerte
>0.5 Muy fuerte
""")
# Out:
# <0.1 Débil
# 0.1-0.3 Media
# 0.3-0.5 Fuerte
# >0.5 Muy fuerte

# %%
var = [v for v in df.columns if v != tgt]
var
# Out:
# ['n_Estado civil',
#  'n_¿Tienes alguna dificultad para? [👓 Ver]',
#  'n_¿Dónde vives actualmente?',
#  'n_¿En qué delegación o municipio?',
#  'n_¿Qué medio de transporte utilizas para llegar a la facultad?',
#  'n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?',
#  'n_¿Con quién vives? (Puedes seleccionar más de una)',
#  'n_¿Cuál es el máximo nivel de estudios de tu papá?',
#  'n_¿Cuál es el máximo nivel de estudios de tu mamá?',
#  'n_En caso de que tengas smartphone ¿Qué sistema operativo tiene?',
#  'n_¿Dónde vivirás mientras cursas tus estudios universitarios?',
#  'n_¿De qué forma financiarás tus estudios universitarios?',
#  'n_¿En dónde cursaste el bachillerato?',
#  'n_¿Cómo se llama la institución donde cursaste el bachillerato?',
#  'n_¿Recibiste alguna beca?',
#  'n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?',
#  'n_Escoger ésta carrera fue...',
#  'n_Al escoger la FES Acatlán ésta fue:',
#  'n_¿Cuándo tomaste la decisión de lo que querías estudiar?',
#  'd_Edad 🎂_2_uni',
#  'd_Edad 🎂_3_uni',
#  'd_Edad 🎂_4_uni',
#  'd_Edad 🎂_5_uni',
#  'd_Edad 🎂_2_qua',
#  'd_Edad 🎂_3_qua',
#  'd_Edad 🎂_4_qua',
#  'd_Edad 🎂_5_qua',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_2_uni',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_3_uni',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_4_uni',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_5_uni',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_2_qua',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_3_qua',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_4_qua',
#  'd_¿Cuánto tiempo dura (en minutos) el trayecto de tu casa a la facultad? ⏱_5_qua',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_2_uni',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_3_uni',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_4_uni',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_uni',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_2_qua',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_3_qua',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_4_qua',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua',
#  'd_¿Cuántos son hombres?_2_uni',
#  'd_¿Cuántos son hombres?_3_uni',
#  'd_¿Cuántos son hombres?_4_uni',
#  'd_¿Cuántos son hombres?_5_uni',
#  'd_¿Cuántos son hombres?_2_qua',
#  'd_¿Cuántos son hombres?_3_qua',
#  'd_¿Cuántos son hombres?_4_qua',
#  'd_¿Cuántos son hombres?_5_qua',
#  'd_¿Cuántas son mujeres?_2_uni',
#  'd_¿Cuántas son mujeres?_3_uni',
#  'd_¿Cuántas son mujeres?_4_uni',
#  'd_¿Cuántas son mujeres?_5_uni',
#  'd_¿Cuántas son mujeres?_2_qua',
#  'd_¿Cuántas son mujeres?_3_qua',
#  'd_¿Cuántas son mujeres?_4_qua',
#  'd_¿Cuántas son mujeres?_5_qua',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_2_uni',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_3_uni',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_4_uni',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_5_uni',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_2_qua',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_3_qua',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_4_qua',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_2_uni',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_3_uni',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_4_uni',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_5_uni',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_2_qua',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_3_qua',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_4_qua',
#  'd_¿Cuántos cuartos para dormir tiene tu vivienda?_5_qua',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_2_uni',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_3_uni',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_4_uni',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_5_uni',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_2_qua',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_3_qua',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_4_qua',
#  'd_¿Cuántos automóviles en total tienen las personas que conforman tu hogar?_5_qua',
#  'd_¿Cuántas horas trabajas a la semana?_2_uni',
#  'd_¿Cuántas horas trabajas a la semana?_3_uni',
#  'd_¿Cuántas horas trabajas a la semana?_4_uni',
#  'd_¿Cuántas horas trabajas a la semana?_5_uni',
#  'd_¿Cuántas horas trabajas a la semana?_2_qua',
#  'd_¿Cuántas horas trabajas a la semana?_3_qua',
#  'd_¿Cuántas horas trabajas a la semana?_4_qua',
#  'd_¿Cuántas horas trabajas a la semana?_5_qua',
#  'd_¿Qué promedio obtuviste en el bachillerato?_2_uni',
#  'd_¿Qué promedio obtuviste en el bachillerato?_3_uni',
#  'd_¿Qué promedio obtuviste en el bachillerato?_4_uni',
#  'd_¿Qué promedio obtuviste en el bachillerato?_5_uni',
#  'd_¿Qué promedio obtuviste en el bachillerato?_2_qua',
#  'd_¿Qué promedio obtuviste en el bachillerato?_3_qua',
#  'd_¿Qué promedio obtuviste en el bachillerato?_4_qua',
#  'd_¿Qué promedio obtuviste en el bachillerato?_5_qua',
#  'd_¿En cuántos años lo terminaste?_2_uni',
#  'd_¿En cuántos años lo terminaste?_3_uni',
#  'd_¿En cuántos años lo terminaste?_4_uni',
#  'd_¿En cuántos años lo terminaste?_5_uni',
#  'd_¿En cuántos años lo terminaste?_2_qua',
#  'd_¿En cuántos años lo terminaste?_3_qua',
#  'd_¿En cuántos años lo terminaste?_4_qua',
#  'd_¿En cuántos años lo terminaste?_5_qua',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_2_uni',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_3_uni',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_4_uni',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_5_uni',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_2_qua',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_3_qua',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_4_qua',
#  'd_¿A cuánto aproximadamente ascienden los ingresos de tu hogar(considerando a todos los que aportan)?_5_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_2_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_3_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_4_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_5_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_2_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_3_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_4_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Deportes ⚽️🏀🏈]_5_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_2_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_3_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_4_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_5_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_2_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_3_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_4_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades culturales 🎭🎬🎻]_5_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_2_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_3_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_4_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_5_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_2_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_3_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_4_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Actividades sociales (fiestas, reuniones con amigos, familia, etc.)]_5_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_2_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_3_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_4_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_uni',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_2_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_3_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_4_qua',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua']

# %%
ivdf = pd.DataFrame(map(lambda v:iv(df,v,tgt),var),columns=['variable','iv'])
ivdf = ivdf.sort_values(by='iv',ascending=False).reset_index(drop=True)
ivdf['iv'].replace({np.inf:np.nan,-np.inf:np.nan},inplace=True)# podemos tratar más fácil a nan
ivdf = ivdf.dropna().reset_index(drop=True)
ivdf['raiz'] = ivdf['variable'].map(lambda x:x.split('_')[1] if x[:2]=='d_' else x)
ivdf = ivdf.sort_values(by=['raiz','iv'],ascending=[1,0]).reset_index(drop=True)
ivdf['best'] = ivdf.groupby('raiz').cumcount()+1
ivdf = ivdf.loc[ivdf['best']==1].drop('best',axis=1).sort_values(by='iv',ascending=False).reset_index(drop=True)
ivdf.head()
# Out:
#                                             variable     iv  \
# 0  d_¿Qué promedio obtuviste en el bachillerato?_... 2.0270
# 1                      n_Escoger ésta carrera fue... 1.1980
# 2  n_¿Cuál fue el proceso de admisión por el que ... 0.4220
# 3  n_¿Cuándo tomaste la decisión de lo que quería... 0.3481
# 4            d_¿En cuántos años lo terminaste?_3_uni 0.3199
#
#                                                 raiz
# 0        ¿Qué promedio obtuviste en el bachillerato?
# 1                      n_Escoger ésta carrera fue...
# 2  n_¿Cuál fue el proceso de admisión por el que ...
# 3  n_¿Cuándo tomaste la decisión de lo que quería...
# 4                    ¿En cuántos años lo terminaste?

# %%
best = ivdf.loc[ivdf['iv']>=0.1]['variable'].tolist()

# %%
best
# Out:
# ['d_¿Qué promedio obtuviste en el bachillerato?_4_qua',
#  'n_Escoger ésta carrera fue...',
#  'n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?',
#  'n_¿Cuándo tomaste la decisión de lo que querías estudiar?',
#  'd_¿En cuántos años lo terminaste?_3_uni',
#  'n_¿En dónde cursaste el bachillerato?',
#  'd_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua',
#  'n_¿Recibiste alguna beca?',
#  'n_Al escoger la FES Acatlán ésta fue:',
#  'n_¿Cómo se llama la institución donde cursaste el bachillerato?',
#  'd_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua',
#  'd_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua',
#  'n_¿Cuál es el máximo nivel de estudios de tu mamá?',
#  'n_¿Cuál es el máximo nivel de estudios de tu papá?']

# %% [markdown]
# ## Transformación WoE

# %%
X = df[best].copy()
y = df[[tgt]].copy()

# %%
Xt,Xv,yt,yv = train_test_split(X,y,train_size=0.7)

# %%
Xt[tgt] = yt

# %%
def woe(df,v,tgt):
    aux = df[[v,tgt]].assign(n=1)
    aux = aux.pivot_table(index=v,
                    columns=tgt,
                    values='n',
                    fill_value=0,
                    aggfunc='sum')
    for i in range(2):
        aux[i]/=aux[i].sum()
    aux['woe'] = np.log(aux[0]/aux[1])
    aux.drop(range(2),axis=1,inplace=True)
    return v,aux.to_dict()['woe']

# %%
woe(df,v,tgt)
# Out:
# ('n_¿Cuál de las siguientes opciones describe tu tipo de vivienda?',
#  {'Ocupada sin pagar renta (incluye casa de familiares)': 0.09782042338453845,
#   'Propia (se esta pagando)': 0.061452779213663516,
#   'Propia (ya esta pagada)': -0.06638059229622123,
#   'Rentada': 0.012662615044231714})

# %%
mapa_woe = list(map(lambda v:woe(Xt,v,tgt),best))

# %%
for v,d in mapa_woe:
    Xt[f'w_{v}'] = Xt[v].replace(d)
    Xv[f'w_{v}'] = Xv[v].replace(d)

# %%
varw = [v for v in Xt.columns if v[:2]=='w_']
varw
# Out:
# ['w_d_¿Qué promedio obtuviste en el bachillerato?_4_qua',
#  'w_n_Escoger ésta carrera fue...',
#  'w_n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?',
#  'w_n_¿Cuándo tomaste la decisión de lo que querías estudiar?',
#  'w_d_¿En cuántos años lo terminaste?_3_uni',
#  'w_n_¿En dónde cursaste el bachillerato?',
#  'w_d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua',
#  'w_n_¿Recibiste alguna beca?',
#  'w_n_Al escoger la FES Acatlán ésta fue:',
#  'w_n_¿Cómo se llama la institución donde cursaste el bachillerato?',
#  'w_d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua',
#  'w_d_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua',
#  'w_n_¿Cuál es el máximo nivel de estudios de tu mamá?',
#  'w_n_¿Cuál es el máximo nivel de estudios de tu papá?']

# %%
Xt = Xt[varw]
Xv = Xv[varw]

# %%
aux = pd.concat([Xt,Xv])
aux = aux.describe().T[['max']]
aux['max'] = np.abs(aux['max'])
aux
# Out:
#                                                       max
# w_d_¿Qué promedio obtuviste en el bachillerato?... 2.3811
# w_n_Escoger ésta carrera fue...                       inf
# w_n_¿Cuál fue el proceso de admisión por el que... 1.4648
# w_n_¿Cuándo tomaste la decisión de lo que querí... 2.7175
# w_d_¿En cuántos años lo terminaste?_3_uni          1.8702
# w_n_¿En dónde cursaste el bachillerato?            0.9658
# w_d_¿Cuántos días a la semana dedicas tiempo pa... 0.8770
# w_n_¿Recibiste alguna beca?                        0.6319
# w_n_Al escoger la FES Acatlán ésta fue:            0.3478
# w_n_¿Cómo se llama la institución donde cursast... 0.7716
# w_d_¿Cuántas personas en total viven en tu hoga... 0.6916
# w_d_¿Cuánto tiempo llevas viviendo ahí? (años)_... 1.3312
# w_n_¿Cuál es el máximo nivel de estudios de tu ... 0.4351
# w_n_¿Cuál es el máximo nivel de estudios de tu ... 0.4693

# %%
quitar = aux.loc[np.isinf(aux['max'])].index.tolist()
quitar
# Out:
# ['w_n_Escoger ésta carrera fue...']

# %%
varw = [v for v in varw if v not in quitar]

# %%
Xt = Xt[varw]
Xv = Xv[varw]

# %% [markdown]
# ## Entrenamiento del modelo

# %%
modelo = LogisticRegression()

# %%
Xt.describe()
# Out:
#        w_d_¿Qué promedio obtuviste en el bachillerato?_4_qua  \
# count                                           155.0000
# mean                                             -0.2237
# std                                               1.5977
# min                                              -1.3684
# 25%                                              -1.1743
# 50%                                              -1.1743
# 75%                                               2.3811
# max                                               2.3811
#
#        w_n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?  \
# count                                           155.0000
# mean                                             -0.0497
# std                                               0.6978
# min                                              -0.3691
# 25%                                              -0.3691
# 50%                                              -0.3691
# 75%                                              -0.3691
# max                                               1.4648
#
#        w_n_¿Cuándo tomaste la decisión de lo que querías estudiar?  \
# count                                           155.0000
# mean                                             -0.0378
# std                                               0.7816
# min                                              -1.1743
# 25%                                              -0.2470
# 50%                                              -0.2470
# 75%                                               0.4662
# max                                               2.7175
#
#        w_d_¿En cuántos años lo terminaste?_3_uni  \
# count                                   155.0000
# mean                                     -0.0109
# std                                       0.4518
# min                                      -0.1254
# 25%                                      -0.1254
# 50%                                      -0.1254
# 75%                                      -0.1254
# max                                       1.8702
#
#        w_n_¿En dónde cursaste el bachillerato?  \
# count                                 155.0000
# mean                                   -0.0550
# std                                     0.6059
# min                                    -0.6147
# 25%                                    -0.3970
# 50%                                    -0.3970
# 75%                                     0.7716
# max                                     0.9658
#
#        w_d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua  \
# count                                           155.0000
# mean                                             -0.0447
# std                                               0.5194
# min                                              -0.8378
# 25%                                              -0.3059
# 50%                                              -0.3059
# 75%                                               0.5485
# max                                               0.8770
#
#        w_n_¿Recibiste alguna beca?  w_n_Al escoger la FES Acatlán ésta fue:  \
# count                     155.0000                                 155.0000
# mean                       -0.0270                                  -0.0438
# std                         0.4096                                   0.4766
# min                        -0.2799                                  -0.7544
# 25%                        -0.2799                                  -0.4811
# 50%                        -0.2799                                   0.3478
# 75%                         0.6319                                   0.3478
# max                         0.6319                                   0.3478
#
#        w_n_¿Cómo se llama la institución donde cursaste el bachillerato?  \
# count                                           155.0000
# mean                                             -0.0390
# std                                               0.4448
# min                                              -1.5310
# 25%                                               0.0340
# 50%                                               0.0340
# 75%                                               0.0340
# max                                               0.7716
#
#        w_d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua  \
# count                                           155.0000
# mean                                             -0.0255
# std                                               0.3884
# min                                              -0.4570
# 25%                                              -0.4570
# 50%                                               0.0297
# 75%                                               0.0785
# max                                               0.6916
#
#        w_d_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua  \
# count                                           155.0000
# mean                                             -0.0298
# std                                               0.4859
# min                                              -0.3523
# 25%                                              -0.3523
# 50%                                              -0.2317
# 75%                                              -0.1447
# max                                               1.3312
#
#        w_n_¿Cuál es el máximo nivel de estudios de tu mamá?  \
# count                                           155.0000
# mean                                             -0.0230
# std                                               0.3539
# min                                              -0.7325
# 25%                                              -0.3598
# 50%                                              -0.0016
# 75%                                               0.3662
# max                                               0.4351
#
#        w_n_¿Cuál es el máximo nivel de estudios de tu papá?
# count                                           155.0000
# mean                                             -0.0570
# std                                               0.5379
# min                                              -1.6263
# 25%                                              -0.2743
# 50%                                               0.0785
# 75%                                               0.4693
# max                                               0.4693

# %%
modelo.fit(Xt,yt)
# Out:
# LogisticRegression()

# %%
print(roc_auc_score(y_score=modelo.predict_proba(Xt)[:,1],y_true=yt))
print(roc_auc_score(y_score=modelo.predict_proba(Xv)[:,1],y_true=yv))
# Out:
# 0.9295340777820562
# 0.8474747474747475

# %% [markdown]
# ## Transformación Scoring

# %%
betas = modelo.coef_[0].tolist()
alpha = modelo.intercept_[0]

# %%
alpha
# Out:
# 0.7176370259986127

# %% [markdown]
# score_base(score al cual vamos a alinear los momios base), odds_base (momios_base),pdo (points to double the odd's)

# %%
score_base = 137 # Empieza aquí
odd_base = 2 #
pdo = 20 # Es decir que en 157 odds=4 y en scorebase=117 odds=1

# %% [markdown]
# $factor = pdo/\log(2)\newline
# offset = score\_base-factor\log(odds\_base)
# \newline
# pts = \left(-WoE\cdot\beta+\alpha/n\right)\cdot factor+offset/n
# $

# %%
factor = pdo/np.log(2)
offset = score_base-factor*np.log(odd_base)

# %%
Xt[tgt] = yt
Xv[tgt] = yv

# %%
X = pd.concat([Xt,Xv],ignore_index=True)

# %%
n = len(varw)

# %%
for b,v in zip(betas,varw):
    X[f'pts_{v}'] = np.ceil((-X[v]*b+alpha/n)*factor+offset/n).astype(int)

# %%
X['score'] = X.filter(like='pts_').sum(axis=1)
X.head()
# Out:
#    w_d_¿Qué promedio obtuviste en el bachillerato?_4_qua  \
# 0                                            -1.0201
# 1                                            -1.1743
# 2                                            -1.0201
# 3                                             2.3811
# 4                                            -1.3684
#
#    w_n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?  \
# 0                                            -0.3691
# 1                                            -0.3691
# 2                                            -0.3691
# 3                                             1.4648
# 4                                            -0.3691
#
#    w_n_¿Cuándo tomaste la decisión de lo que querías estudiar?  \
# 0                                            -0.2470
# 1                                            -1.1743
# 2                                            -0.2470
# 3                                            -0.2470
# 4                                             0.4662
#
#    w_d_¿En cuántos años lo terminaste?_3_uni  \
# 0                                    -0.1254
# 1                                    -0.1254
# 2                                    -0.1254
# 3                                    -0.1254
# 4                                    -0.1254
#
#    w_n_¿En dónde cursaste el bachillerato?  \
# 0                                  -0.3970
# 1                                  -0.3970
# 2                                  -0.3970
# 3                                   0.9658
# 4                                  -0.3970
#
#    w_d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua  \
# 0                                            -0.3059
# 1                                            -0.1447
# 2                                            -0.3059
# 3                                             0.5485
# 4                                             0.5485
#
#    w_n_¿Recibiste alguna beca?  w_n_Al escoger la FES Acatlán ésta fue:  \
# 0                      -0.2799                                   0.3478
# 1                      -0.2799                                  -0.7544
# 2                      -0.2799                                   0.3478
# 3                       0.6319                                   0.3478
# 4                      -0.2799                                  -0.4811
#
#    w_n_¿Cómo se llama la institución donde cursaste el bachillerato?  \
# 0                                             0.0340
# 1                                             0.0340
# 2                                             0.0340
# 3                                             0.0340
# 4                                             0.0340
#
#    w_d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua  \
# 0                                             0.6916
# 1                                            -0.0757
# 2                                            -0.4570
# 3                                             0.6916
# 4                                             0.6916
#
#    w_d_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua  \
# 0                                            -0.2317
# 1                                            -0.1447
# 2                                            -0.1447
# 3                                             0.5893
# 4                                            -0.1447
#
#    w_n_¿Cuál es el máximo nivel de estudios de tu mamá?  \
# 0                                             0.4351
# 1                                            -0.0016
# 2                                            -0.0016
# 3                                            -0.0016
# 4                                            -0.3598
#
#    w_n_¿Cuál es el máximo nivel de estudios de tu papá?  Carrera  \
# 0                                             0.0785           1
# 1                                            -0.2743           1
# 2                                             0.4693           1
# 3                                             0.4693           0
# 4                                             0.4693           1
#
#    pts_w_d_¿Qué promedio obtuviste en el bachillerato?_4_qua  \
# 0                                                -16
# 1                                                -20
# 2                                                -16
# 3                                                 74
# 4                                                -25
#
#    pts_w_n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?  \
# 0                                                  8
# 1                                                  8
# 2                                                  8
# 3                                                 22
# 4                                                  8
#
#    pts_w_n_¿Cuándo tomaste la decisión de lo que querías estudiar?  \
# 0                                                  8
# 1                                                 -5
# 2                                                  8
# 3                                                  8
# 4                                                 18
#
#    pts_w_d_¿En cuántos años lo terminaste?_3_uni  \
# 0                                             10
# 1                                             10
# 2                                             10
# 3                                             10
# 4                                             10
#
#    pts_w_n_¿En dónde cursaste el bachillerato?  \
# 0                                            5
# 1                                            5
# 2                                            5
# 3                                           26
# 4                                            5
#
#    pts_w_d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua  \
# 0                                                  8
# 1                                                  9
# 2                                                  8
# 3                                                 17
# 4                                                 17
#
#    pts_w_n_¿Recibiste alguna beca?  \
# 0                                9
# 1                                9
# 2                                9
# 3                               16
# 4                                9
#
#    pts_w_n_Al escoger la FES Acatlán ésta fue:  \
# 0                                           18
# 1                                           -4
# 2                                           18
# 3                                           18
# 4                                            1
#
#    pts_w_n_¿Cómo se llama la institución donde cursaste el bachillerato?  \
# 0                                                 12
# 1                                                 12
# 2                                                 12
# 3                                                 12
# 4                                                 12
#
#    pts_w_d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua  \
# 0                                                 17
# 1                                                 10
# 2                                                  7
# 3                                                 17
# 4                                                 17
#
#    pts_w_d_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua  \
# 0                                                 12
# 1                                                 11
# 2                                                 11
# 3                                                  9
# 4                                                 11
#
#    pts_w_n_¿Cuál es el máximo nivel de estudios de tu mamá?  \
# 0                                                 16
# 1                                                 11
# 2                                                 11
# 3                                                 11
# 4                                                  7
#
#    pts_w_n_¿Cuál es el máximo nivel de estudios de tu papá?  score
# 0                                                 12           119
# 1                                                  8            64
# 2                                                 16           107
# 3                                                 16           256
# 4                                                 16           106

# %%
X.score.hist()
# Out:
# <AxesSubplot:>

# %%
X['r_score'] = pd.cut(X['score'],bins=range(0,360+36,36)).astype(str)

# %%
isana=X.loc[:,'r_score'].isna()
igual=X.loc[:,'r_score']== '(144.0, 180.0]'
X[['r_score']].loc[isana]
# Out:
# Empty DataFrame
# Columns: [r_score]
# Index: []

# %%
#X.pivot_table(index='r_score',columns=tgt,values='score',aggfunc='count',fill_value=0).to_clipboard()

# %%
X.pivot_table(index='r_score',columns=tgt,values='score',aggfunc='count',fill_value=0).sort_index()
# Out:
# Carrera      0   1
# r_score
# (108, 144]  10  30
# (144, 180]  11   9
# (180, 216]  17   4
# (216, 252]  18   5
# (252, 288]   9   1
# (36, 72]     0  20
# (72, 108]    6  82

# %%
varw
# Out:
# ['w_d_¿Qué promedio obtuviste en el bachillerato?_4_qua',
#  'w_n_¿Cuál fue el proceso de admisión por el que entraste a esta carrera?',
#  'w_n_¿Cuándo tomaste la decisión de lo que querías estudiar?',
#  'w_d_¿En cuántos años lo terminaste?_3_uni',
#  'w_n_¿En dónde cursaste el bachillerato?',
#  'w_d_¿Cuántos días a la semana dedicas tiempo para realizar las siguientes actividades? [Entretenimiento personal (videojuegos, redes sociales, netflix, youtube, etc)]_5_qua',
#  'w_n_¿Recibiste alguna beca?',
#  'w_n_Al escoger la FES Acatlán ésta fue:',
#  'w_n_¿Cómo se llama la institución donde cursaste el bachillerato?',
#  'w_d_¿Cuántas personas en total viven en tu hogar? Incluyéndote a ti_5_qua',
#  'w_d_¿Cuánto tiempo llevas viviendo ahí? (años)_5_qua',
#  'w_n_¿Cuál es el máximo nivel de estudios de tu mamá?',
#  'w_n_¿Cuál es el máximo nivel de estudios de tu papá?']

# %%
l = []
for v,d in mapa_woe:
    if 'w_%s'%v in varw:
        d = {y:x for x,y in d.items()}
        aux = X[['w_%s'%v,'pts_w_%s'%v]].copy()
        aux.drop_duplicates(inplace=True)
        aux['w_%s'%v].replace(d,inplace=True)
        aux.rename(columns={'w_%s'%v:'atributo','pts_w_%s'%v:'puntos'},inplace=True)
        aux['característica'] = v
        l.append(aux)

# %%
l
# Out:
# [       atributo  puntos                                     característica
#  0  (8.5, 8.815]     -18  d_¿Qué promedio obtuviste en el bachillerato?_...
#  1  (8.815, 9.1]     -28  d_¿Qué promedio obtuviste en el bachillerato?_...
#  2  (6.999, 8.5]      74  d_¿Qué promedio obtuviste en el bachillerato?_...
#  4   (9.1, 10.0]      -7  d_¿Qué promedio obtuviste en el bachillerato?_...,
#                  atributo  puntos                 característica
#  0   ❤️ Mi primera opción       1  n_Escoger ésta carrera fue...
#  12   😊 Mi segunda opción      90  n_Escoger ésta carrera fue...,
#                  atributo  puntos  \
#  0      Pase reglamentado       6
#  1  Concurso de selección      25
#
#                                        característica
#  0  n_¿Cuál fue el proceso de admisión por el que ...
#  1  n_¿Cuál fue el proceso de admisión por el que ...  ,
#                             atributo  puntos  \
#  0       Al terminar el bachillerato      16
#  1           Durante el bachillerato       9
#  4            Antes del bachillerato      -4
#  19  En otro momento o circunstancia      19
#
#                                         característica
#  0   n_¿Cuándo tomaste la decisión de lo que quería...
#  1   n_¿Cuándo tomaste la decisión de lo que quería...
#  4   n_¿Cuándo tomaste la decisión de lo que quería...
#  19  n_¿Cuándo tomaste la decisión de lo que quería...  ,
#            atributo  puntos                           característica
#  0   (2.333, 3.667]      11  d_¿En cuántos años lo terminaste?_3_uni
#  23    (3.667, 5.0]       5  d_¿En cuántos años lo terminaste?_3_uni
#  33  (0.999, 2.333]       9  d_¿En cuántos años lo terminaste?_3_uni,
#                                  atributo  puntos  \
#  0   Escuela Nacional Preparatoria (UNAM)       6
#  1                        Escuela privada      18
#  4                                   Otro       8
#  11                       Escuela pública      19
#
#                             característica
#  0   n_¿En dónde cursaste el bachillerato?
#  1   n_¿En dónde cursaste el bachillerato?
#  4   n_¿En dónde cursaste el bachillerato?
#  11  n_¿En dónde cursaste el bachillerato?  ,
#          atributo  puntos                                     característica
#  0     (2.0, 3.0]      -7  d_¿Cuántos días a la semana dedicas tiempo par...
#  1     (1.0, 2.0]      13  d_¿Cuántos días a la semana dedicas tiempo par...
#  3  (-0.001, 1.0]      -1  d_¿Cuántos días a la semana dedicas tiempo par...
#  4     (5.0, 7.0]      18  d_¿Cuántos días a la semana dedicas tiempo par...
#  9     (3.0, 5.0]      29  d_¿Cuántos días a la semana dedicas tiempo par...,
#    atributo  puntos             característica
#  0       Sí       6  n_¿Recibiste alguna beca?
#  1       No      19  n_¿Recibiste alguna beca?,
#                      atributo  puntos                         característica
#  0  ☔️ No quería este plantel       0  n_Al escoger la FES Acatlán ésta fue:
#  1       ☀️ Mi primera opción      15  n_Al escoger la FES Acatlán ésta fue:
#  9       ⛅️ Mi segunda opción       2  n_Al escoger la FES Acatlán ésta fue:,
#           atributo  puntos                                     característica
#  0           Otros      12  n_¿Cómo se llama la institución donde cursaste...
#  6             CCH     -48  n_¿Cómo se llama la institución donde cursaste...
#  36  CCH Naucalpan      38  n_¿Cómo se llama la institución donde cursaste...,
#          atributo  puntos                                     característica
#  0   (0.999, 3.0]      14  d_¿Cuántas personas en total viven en tu hogar...
#  2     (5.0, 6.0]      15  d_¿Cuántas personas en total viven en tu hogar...
#  3     (3.0, 4.0]       6  d_¿Cuántas personas en total viven en tu hogar...
#  8    (6.0, 12.0]       5  d_¿Cuántas personas en total viven en tu hogar...
#  14    (4.0, 5.0]      11  d_¿Cuántas personas en total viven en tu hogar...,
#          atributo  puntos                                     característica
#  0  (-0.001, 5.0]       9  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
#  1   (18.0, 35.0]      12  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
#  3    (5.0, 11.4]      12  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
#  4   (11.4, 17.0]      11  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
#  5   (17.0, 18.0]       9  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...,
#                           atributo  puntos  \
#  0                    Bachillerato      10
#  3                      Secundaria      22
#  9                    Licenciatura      -4
#  15                       Primaria       0
#  19  Posgrado, maestria, doctorado      27
#
#                                         característica
#  0   n_¿Cuál es el máximo nivel de estudios de tu m...
#  3   n_¿Cuál es el máximo nivel de estudios de tu m...
#  9   n_¿Cuál es el máximo nivel de estudios de tu m...
#  15  n_¿Cuál es el máximo nivel de estudios de tu m...
#  19  n_¿Cuál es el máximo nivel de estudios de tu m...  ,
#         atributo  puntos                                     característica
#  0  Licenciatura       8  n_¿Cuál es el máximo nivel de estudios de tu p...
#  2      Primaria      11  n_¿Cuál es el máximo nivel de estudios de tu p...
#  3    Secundaria      15  n_¿Cuál es el máximo nivel de estudios de tu p...
#  4  Bachillerato       9  n_¿Cuál es el máximo nivel de estudios de tu p...]

# %%
scorecard = pd.concat(l,ignore_index=True)
scorecard
# Out:
#                                 atributo  puntos  \
# 0                           (8.5, 8.815]     -18
# 1                           (8.815, 9.1]     -28
# 2                           (6.999, 8.5]      74
# 3                            (9.1, 10.0]      -7
# 4                   ❤️ Mi primera opción       1
# 5                    😊 Mi segunda opción      90
# 6                      Pase reglamentado       6
# 7                  Concurso de selección      25
# 8            Al terminar el bachillerato      16
# 9                Durante el bachillerato       9
# 10                Antes del bachillerato      -4
# 11       En otro momento o circunstancia      19
# 12                        (2.333, 3.667]      11
# 13                          (3.667, 5.0]       5
# 14                        (0.999, 2.333]       9
# 15  Escuela Nacional Preparatoria (UNAM)       6
# 16                       Escuela privada      18
# 17                                  Otro       8
# 18                       Escuela pública      19
# 19                            (2.0, 3.0]      -7
# 20                            (1.0, 2.0]      13
# 21                         (-0.001, 1.0]      -1
# 22                            (5.0, 7.0]      18
# 23                            (3.0, 5.0]      29
# 24                                    Sí       6
# 25                                    No      19
# 26             ☔️ No quería este plantel       0
# 27                  ☀️ Mi primera opción      15
# 28                  ⛅️ Mi segunda opción       2
# 29                                 Otros      12
# 30                                   CCH     -48
# 31                         CCH Naucalpan      38
# 32                          (0.999, 3.0]      14
# 33                            (5.0, 6.0]      15
# 34                            (3.0, 4.0]       6
# 35                           (6.0, 12.0]       5
# 36                            (4.0, 5.0]      11
# 37                         (-0.001, 5.0]       9
# 38                          (18.0, 35.0]      12
# 39                           (5.0, 11.4]      12
# 40                          (11.4, 17.0]      11
# 41                          (17.0, 18.0]       9
# 42                          Bachillerato      10
# 43                            Secundaria      22
# 44                          Licenciatura      -4
# 45                              Primaria       0
# 46         Posgrado, maestria, doctorado      27
# 47                          Licenciatura       8
# 48                              Primaria      11
# 49                            Secundaria      15
# 50                          Bachillerato       9
#
#                                        característica
# 0   d_¿Qué promedio obtuviste en el bachillerato?_...
# 1   d_¿Qué promedio obtuviste en el bachillerato?_...
# 2   d_¿Qué promedio obtuviste en el bachillerato?_...
# 3   d_¿Qué promedio obtuviste en el bachillerato?_...
# 4                       n_Escoger ésta carrera fue...
# 5                       n_Escoger ésta carrera fue...
# 6   n_¿Cuál fue el proceso de admisión por el que ...
# 7   n_¿Cuál fue el proceso de admisión por el que ...
# 8   n_¿Cuándo tomaste la decisión de lo que quería...
# 9   n_¿Cuándo tomaste la decisión de lo que quería...
# 10  n_¿Cuándo tomaste la decisión de lo que quería...
# 11  n_¿Cuándo tomaste la decisión de lo que quería...
# 12            d_¿En cuántos años lo terminaste?_3_uni
# 13            d_¿En cuántos años lo terminaste?_3_uni
# 14            d_¿En cuántos años lo terminaste?_3_uni
# 15              n_¿En dónde cursaste el bachillerato?
# 16              n_¿En dónde cursaste el bachillerato?
# 17              n_¿En dónde cursaste el bachillerato?
# 18              n_¿En dónde cursaste el bachillerato?
# 19  d_¿Cuántos días a la semana dedicas tiempo par...
# 20  d_¿Cuántos días a la semana dedicas tiempo par...
# 21  d_¿Cuántos días a la semana dedicas tiempo par...
# 22  d_¿Cuántos días a la semana dedicas tiempo par...
# 23  d_¿Cuántos días a la semana dedicas tiempo par...
# 24                          n_¿Recibiste alguna beca?
# 25                          n_¿Recibiste alguna beca?
# 26              n_Al escoger la FES Acatlán ésta fue:
# 27              n_Al escoger la FES Acatlán ésta fue:
# 28              n_Al escoger la FES Acatlán ésta fue:
# 29  n_¿Cómo se llama la institución donde cursaste...
# 30  n_¿Cómo se llama la institución donde cursaste...
# 31  n_¿Cómo se llama la institución donde cursaste...
# 32  d_¿Cuántas personas en total viven en tu hogar...
# 33  d_¿Cuántas personas en total viven en tu hogar...
# 34  d_¿Cuántas personas en total viven en tu hogar...
# 35  d_¿Cuántas personas en total viven en tu hogar...
# 36  d_¿Cuántas personas en total viven en tu hogar...
# 37  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
# 38  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
# 39  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
# 40  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
# 41  d_¿Cuánto tiempo llevas viviendo ahí? (años)_5...
# 42  n_¿Cuál es el máximo nivel de estudios de tu m...
# 43  n_¿Cuál es el máximo nivel de estudios de tu m...
# 44  n_¿Cuál es el máximo nivel de estudios de tu m...
# 45  n_¿Cuál es el máximo nivel de estudios de tu m...
# 46  n_¿Cuál es el máximo nivel de estudios de tu m...
# 47  n_¿Cuál es el máximo nivel de estudios de tu p...
# 48  n_¿Cuál es el máximo nivel de estudios de tu p...
# 49  n_¿Cuál es el máximo nivel de estudios de tu p...
# 50  n_¿Cuál es el máximo nivel de estudios de tu p...

# %%
with pd.ExcelWriter('scorecard.xlsx') as xl:
    scorecard.groupby(['característica','atributo']).max().to_excel(xl,sheet_name='scorecard')
    xl.close()
